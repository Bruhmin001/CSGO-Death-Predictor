# %%
from Bruhmin import turkeyhsd
import seaborn as sns
from sklearn.preprocessing import scale
import sklearn.linear_model as lm
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
import scipy.stats as stats
from statsmodels.stats.outliers_influence import variance_inflation_factor
import numpy as np
import pandas as pd
from  statsmodels.api import stats  as sm
from statsmodels.formula.api import ols
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import statsmodels.stats.multicomp as mc
from statsmodels.stats.proportion import proportions_ztest as prop
from scipy import stats
from statsmodels.multivariate.manova import MANOVA 
import cv2
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv("gaytaset.csv")
df
# Out:
#       CountryCode        subset  question_code  \
# 0         Austria       Lesbian           b1_a
# 1         Austria       Lesbian           b1_a
# 2         Austria       Lesbian           b1_a
# 3         Austria       Lesbian           b1_a
# 4         Austria       Lesbian           b1_a
# ...           ...           ...            ...
# 34015     Average  Bisexual men  openness_cat4
# 34016     Average   Transgender  openness_cat4
# 34017     Average   Transgender  openness_cat4
# 34018     Average   Transgender  openness_cat4
# 34019     Average   Transgender  openness_cat4
#
#                                           question_label             answer  \
# 0      In your opinion, how widespread is offensive l...    Very widespread
# 1      In your opinion, how widespread is offensive l...  Fairly widespread
# 2      In your opinion, how widespread is offensive l...        Fairly rare
# 3      In your opinion, how widespread is offensive l...          Very rare
# ...

# %%
q_code = list(df['question_code'].unique())
q_code
# Out:
# ['b1_a',
#  'b1_b',
#  'b1_c',
#  'b1_d',
#  'b1_e',
#  'b1_f',
#  'b1_g',
#  'b1_h',
#  'b1_i',
#  'b2_a',
#  'b2_b',
#  'b2_c',
#  'b2_d',
#  'b2_e',
#  'b2_f',
#  'b2_g',
#  'b2_h',
#  'b2_i',
#  'c1a_a',
#  'c1a_b',
#  'c1a_c',
#  'c1a_d',
#  'c1_b',
#  'c1_c',
#  'g1_a',
#  'g2_a',
#  'g2_b',
#  'g2_c',
#  'g2_d',
#  'g3_a',
#  'g3_b',
#  'g3_c',
#  'g3_d',
#  'g3_e',
#  'g3_f',
#  'g3_g',
#  'g4_a',
#  'g4_b',
#  'g4_c',
#  'g5',
#  'h10',
#  'h11',
#  'h14',
#  'h15',
#  'h16',
#  'h9',
#  'h9_1',
#  'h9_2',
#  'i1',
#  'open_at_school',
#  'open_at_work',
#  'openness_cat4']

# %%
# for i in range(0,len(q_code)):
#     for j in range(0,len(q_code)):
#         df exec() = df[df['question_code'] == q_code]

# %%
df1 = df[df['question_code'] == "b1_a"]
df1
# Out:
#     CountryCode       subset question_code  \
# 0       Austria      Lesbian          b1_a
# 1       Austria      Lesbian          b1_a
# 2       Austria      Lesbian          b1_a
# 3       Austria      Lesbian          b1_a
# 4       Austria      Lesbian          b1_a
# ..          ...          ...           ...
# 720     Average  Transgender          b1_a
# 721     Average  Transgender          b1_a
# 722     Average  Transgender          b1_a
# 723     Average  Transgender          b1_a
# 724     Average  Transgender          b1_a
#
#                                         question_label             answer  \
# 0    In your opinion, how widespread is offensive l...    Very widespread
# 1    In your opinion, how widespread is offensive l...  Fairly widespread
# 2    In your opinion, how widespread is offensive l...        Fairly rare
# 3    In your opinion, how widespread is offensive l...          Very rare
# ...

# %%
le = LabelEncoder()
df1['answer'] = le.fit_transform(df1['answer'])
print(dict(zip(le.classes_, le.transform(le.classes_))))
# Out:
# {'Don`t know': 0, 'Fairly rare': 1, 'Fairly widespread': 2, 'Very rare': 3, 'Very widespread': 4}
# C:\Users\Khush Trivedi\AppData\Local\Temp\ipykernel_12292\866740671.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['answer'] = le.fit_transform(df1['answer'])

# %%
le = LabelEncoder()
df1['subset'] = le.fit_transform(df1['subset'])
print(dict(zip(le.classes_, le.transform(le.classes_))))
# Out:
# {'Bisexual men': 0, 'Bisexual women': 1, 'Gay': 2, 'Lesbian': 3, 'Transgender': 4}
# C:\Users\Khush Trivedi\AppData\Local\Temp\ipykernel_12292\215674766.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['subset'] = le.fit_transform(df1['subset'])

# %%
df1
# Out:
#     CountryCode  subset question_code  \
# 0       Austria       3          b1_a
# 1       Austria       3          b1_a
# 2       Austria       3          b1_a
# 3       Austria       3          b1_a
# 4       Austria       3          b1_a
# ..          ...     ...           ...
# 720     Average       4          b1_a
# 721     Average       4          b1_a
# 722     Average       4          b1_a
# 723     Average       4          b1_a
# 724     Average       4          b1_a
#
#                                         question_label  answer percentage  \
# 0    In your opinion, how widespread is offensive l...       4          8
# 1    In your opinion, how widespread is offensive l...       2         34
# 2    In your opinion, how widespread is offensive l...       1         45
# 3    In your opinion, how widespread is offensive l...       3          9
# 4    In your opinion, how widespread is offensive l...       0          4
# ...

# %%
i = 5

# %%
df0 = pd.read_parquet(f"D:/SSDI_Project/matchdata_split/natus-vincere-vs-faze-m1-dust2/{i}/Round-{i}_Player-1.parquet")
df0
# Out:
#      roundNum   tick   hp  armor   activeWeapon  isBlinded  isAirborne  \
# 0           5      0  100     92    Melee Kills      False       False
# 1           5    128  100     92    Melee Kills      False       False
# 2           5    256  100     92    Melee Kills      False       False
# 3           5    384  100     92    Melee Kills      False       False
# 4           5    512  100     92    Melee Kills      False        True
# ..        ...    ...  ...    ...            ...        ...         ...
# 126         5  16147    0      0  Utility Kills      False        True
# 127         5  16275    0      0  Utility Kills      False        True
# 128         5  16403    0      0  Utility Kills      False        True
# 129         5  16531    0      0  Utility Kills      False        True
# 130         5  16659    0      0  Utility Kills      False        True
#
#      isDucking  isStanding  isScoped  ...  team_in_range_200  \
# ...

# %%
"/Round"
# Out:
# '/Round'
